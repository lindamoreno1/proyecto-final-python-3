# %% [markdown]
# # TEMPERATURA

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# 1. Contexto y objetivo del análisis
#         Comisión Federal de Electricidad (CFE) aporta un presupuesto a cada plantel educativo por año. El plantel CBTis 269 se encuentra en la zona baja de la sierra de Ciudad Juárez, debido a esa lacalización las altas y bajas temperaturas se acentuan más, por lo que el plantel debe tener encendidos los aparatos de refrigeracion la mayor parte de la jornada escolar (7:00 - 16:00) lo que ocasiona un enorme gasto en el recibo de la CFE, por lo que en contadas veces han llegado avisos de suspencion del servicio debido a que se agota el presupuesto que se le destina al plantel.

# %% [markdown]
# ## 2. Exploración de Datos

# %%
pagina_web = requests.get("https://es-us.noticias.yahoo.com/clima/mexico/chihuahua/ciudad-juarez-116556")
soup = BeautifulSoup(pagina_web.text, 'html.parser')
print(soup.prettify())

# %% [markdown]
# ### Graficos

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv("../datos/clima.csv")
x=df["Grados Celsius"].unique()
y=df["Grados Celsius"].value_counts().to_list()
plt.bar(x,y)
plt.title("Cuantos dias se registraron cada temperatura")
plt.xlabel("Grados Celsius")
plt.ylabel("Ocurrencias")
plt.figure(figsize=(10, 6))
plt.show()

# %% [markdown]
# Analizando la gráfica se muestra que la temperatura de 35 grados Celsius es la que mas se repite

# %% [markdown]
# ## 3. Conclusiones

# %% [markdown]
# Dedido a las altas temperaturas que se registraron en los días observados, se considera que los aparatos de refrigeración deben seguir prendidos en la jornada escolar, se deberá buscar soluciones alternas para ahorra energia eléctrica.
