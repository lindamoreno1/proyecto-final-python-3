# %% [markdown]
# # ANALISIS EXPLORATORIO DE LA TEMPERATURA EN GRADOS CELSIUS

# %%
import pandas as pd

# %%
df=pd.read_csv("../datos/clima.csv")
df
# Out:
#           Fecha        Dia   Hora  Grados Celsius  Grados Fahrenheit  \
# 0   02 Aug 2023  Wednesday  17:53              35                 94
# 1   02 Aug 2023  Wednesday  18:05              34                 93
# 2   03 Aug 2023   Thursday  08:04              27                 79
# 3   03 Aug 2023   Thursday  08:57              27                 80
# 4   03 Aug 2023   Thursday  10:06              30                 85
# 5   03 Aug 2023   Thursday  11:06              29                 84
# 6   03 Aug 2023   Thursday  12:03              33                 91
# 7   03 Aug 2023   Thursday  13:03              32                 88
# 8   03 Aug 2023   Thursday  14:01              33                 91
# 9   03 Aug 2023   Thursday  16:17              36                 96
# 10  04 Aug 2023     Friday  08:18              27                 80
# 11  04 Aug 2023     Friday  09:06              31                 87
# 12  04 Aug 2023     Friday  09:41              32                 88
# ...

# %%
maximo=df["Grados Celsius"].max
print(maximo)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0     35
# 1     34
# 2     27
# 3     27
# 4     30
# 5     29
# 6     33
# 7     32
# 8     33
# 9     36
# 10    27
# 11    31
# 12    32
# 13    34
# 14    34
# 15    36
# 16    37
# 17    38
# 18    38
# 19    39
# 20    30
# 21    31
# 22    32
# 23    33
# 24    36
# 25    39
# 26    39
# 27    39
# 28    39
# 29    40
# 30    28
# 31    29
# 32    30
# 33    33
# 34    33
# 35    34
# 36    34
# 37    38
# 38    27
# 39    28
# 40    28
# 41    31
# 42    33
# 43    34
# 44    35
# 45    37
# 46    37
# 47    31
# 48    31
# 49    32
# 50    34
# 51    34
# 52    37
# 53    37
# 54    37
# Name: Grados Celsius, dtype: int64>

# %% [markdown]
# # media, mediana y moda  de temperaturas en celsius

# %%
media=df["Grados Celsius"].mean
print (media)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     35
# 1     34
# 2     27
# 3     27
# 4     30
# 5     29
# 6     33
# 7     32
# 8     33
# 9     36
# 10    27
# 11    31
# 12    32
# 13    34
# 14    34
# 15    36
# 16    37
# 17    38
# 18    38
# 19    39
# 20    30
# 21    31
# 22    32
# 23    33
# 24    36
# 25    39
# 26    39
# 27    39
# 28    39
# 29    40
# 30    28
# 31    29
# 32    30
# 33    33
# 34    33
# 35    34
# 36    34
# 37    38
# 38    27
# 39    28
# 40    28
# 41    31
# 42    33
# 43    34
# 44    35
# 45    37
# 46    37
# 47    31
# 48    31
# 49    32
# 50    34
# 51    34
# 52    37
# 53    37
# 54    37
# Name: Grados Celsius, dtype: int64>

# %%
mediana=df["Grados Celsius"].median
print(mediana)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0     35
# 1     34
# 2     27
# 3     27
# 4     30
# 5     29
# 6     33
# 7     32
# 8     33
# 9     36
# 10    27
# 11    31
# 12    32
# 13    34
# 14    34
# 15    36
# 16    37
# 17    38
# 18    38
# 19    39
# 20    30
# 21    31
# 22    32
# 23    33
# 24    36
# 25    39
# 26    39
# 27    39
# 28    39
# 29    40
# 30    28
# 31    29
# 32    30
# 33    33
# 34    33
# 35    34
# 36    34
# 37    38
# 38    27
# 39    28
# 40    28
# 41    31
# 42    33
# 43    34
# 44    35
# 45    37
# 46    37
# 47    31
# 48    31
# 49    32
# 50    34
# 51    34
# 52    37
# 53    37
# 54    37
# Name: Grados Celsius, dtype: int64>

# %%
moda=df["Grados Celsius"].mode
print(moda)
# Out:
# <bound method Series.mode of 0     35
# 1     34
# 2     27
# 3     27
# 4     30
# 5     29
# 6     33
# 7     32
# 8     33
# 9     36
# 10    27
# 11    31
# 12    32
# 13    34
# 14    34
# 15    36
# 16    37
# 17    38
# 18    38
# 19    39
# 20    30
# 21    31
# 22    32
# 23    33
# 24    36
# 25    39
# 26    39
# 27    39
# 28    39
# 29    40
# 30    28
# 31    29
# 32    30
# 33    33
# 34    33
# 35    34
# 36    34
# 37    38
# 38    27
# 39    28
# 40    28
# 41    31
# 42    33
# 43    34
# 44    35
# 45    37
# 46    37
# 47    31
# 48    31
# 49    32
# 50    34
# 51    34
# 52    37
# 53    37
# 54    37
# Name: Grados Celsius, dtype: int64>
